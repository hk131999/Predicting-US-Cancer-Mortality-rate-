# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
def get_data(file_name):
    data=pd.read_csv(file_name)
    return data

# %%
def find_constant_columns(data):
    constant_columns=[]
    for i in data.columns:
        unique_vaalues=data[i].unique()
        if len(unique_values)==1:
            constant_columns.append(i)
    return constant_columns
def delet_constant_columns(data, columns_to delete):
    data.drop(columns_to_delete ,inplace=True,axis=1)
    return data

def find_columns_with_few_values(data,threshold):
    few_value_columns=[]
    for i in data.columns:
        unique_value_count=len(data[i].unique())
        if unique_value_count<threshold:
            fwe_value_columns.append(i)
    return few_value_columns
def find_duplicate_rows(data):
    duplicate_rows=data[data.duplicated()]
    return duplicate_rows
def drop(data):
    cols_with_null=data.columns[data.isnull().sum()>0]
    for i in cols_with_null:
        percent_of_null_values_in_col=((data[i].isnull().sum())/(list(data.shape)[0]))*100
        if(percent_of_null_values_in_col >50):
            data.drop(i,axis=1,inplace=True)
        cols_with_null=data.columns[data.isnull().sum()>0]
    return data,cols_with_null
def fill(data_from_drop,cols_with_null):
    data_without_Na=data_from_drop.dropna(axis=0)
    rows=list(data_without_Na.shape)[0]
    data_with_na_train1=data_without_Na.drop(axis=\)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-17be9f27c6ca> in <module>
# ----> 1 show_data().head()
#
# <ipython-input-104-699129675720> in show_data()
#       4 data=get_data('cancer_reg.csv')
#       5 def show_data():
# ----> 6     return data(data)
#
# TypeError: 'DataFrame' object is not callable

# %%
list(data.shape)[0]
# Out:
# 3047

# %%
data.columns[data.isnull().sum()>0]
# Out:
# Index(['PctSomeCol18_24', 'PctEmployed16_Over', 'PctPrivateCoverageAlone'], dtype='object')

# %%
data['avgAnnCount'].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# avgAnnCount                   0
# avgDeathsPerYear              0
# TARGET_deathRate              0
# incidenceRate                 0
# medIncome                     0
# popEst2015                    0
# povertyPercent                0
# studyPerCap                   0
# binnedInc                     0
# MedianAge                     0
# MedianAgeMale                 0
# MedianAgeFemale               0
# Geography                     0
# AvgHouseholdSize              0
# PercentMarried                0
# PctNoHS18_24                  0
# PctHS18_24                    0
# PctSomeCol18_24            2285
# PctBachDeg18_24               0
# PctHS25_Over                  0
# PctBachDeg25_Over             0
# PctEmployed16_Over          152
# PctUnemployed16_Over          0
# PctPrivateCoverage            0
# PctPrivateCoverageAlone     609
# PctEmpPrivCoverage            0
# PctPublicCoverage             0
# PctPublicCoverageAlone        0
# PctWhite                      0
# ...

# %%
data.drop('PctSomeCol18_24',axis=1,inplace=True) # dropping as the missing values are more than 50%

# %%
data['PctEmployed16_Over'].fillna(data['PctEmployed16_Over'].mean(),inplace=True)
data['PctPrivateCoverageAlone'].fillna(data['PctPrivateCoverageAlone'].mean(),inplace=True)

# %%
data.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap  MedianAge  MedianAgeMale  ...  \
# 0      260131            11.2   499.748204       39.3           36.9  ...
# 1       43269            18.6    23.111234       33.0           32.2  ...
# 2       21026            14.6    47.560164       45.0           44.0  ...
# 3       75882            17.1   342.637253       42.8           42.2  ...
# 4       10321            12.5     0.000000       48.3           47.8  ...
#
# ...

# %%
data.isnull().sum()
# Out:
# avgAnnCount                0
# avgDeathsPerYear           0
# TARGET_deathRate           0
# incidenceRate              0
# medIncome                  0
# popEst2015                 0
# povertyPercent             0
# studyPerCap                0
# MedianAge                  0
# MedianAgeMale              0
# MedianAgeFemale            0
# AvgHouseholdSize           0
# PercentMarried             0
# PctNoHS18_24               0
# PctHS18_24                 0
# PctBachDeg18_24            0
# PctHS25_Over               0
# PctBachDeg25_Over          0
# PctEmployed16_Over         0
# PctUnemployed16_Over       0
# PctPrivateCoverage         0
# PctPrivateCoverageAlone    0
# PctEmpPrivCoverage         0
# PctPublicCoverage          0
# PctPublicCoverageAlone     0
# PctWhite                   0
# PctBlack                   0
# PctAsian                   0
# PctOtherRace               0
# PctMarriedHouseholds       0
# BirthRate                  0
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()

data_scaled=pd.DataFrame(sc.fit_transform(data),columns=data.columns)
data_scaled
# Out:
#       avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  \
# 0        0.036467          0.033269          0.347080       0.286893
# 1        0.004378          0.004783          0.335203       0.209129
# 2        0.002517          0.003355          0.379413       0.147574
# 3        0.011037          0.014207          0.445727       0.227824
# 4        0.001337          0.001642          0.279446       0.147971
# ...           ...               ...               ...            ...
# 3042     0.051297          0.000857          0.296602       0.250845
# 3043     0.051297          0.002856          0.298251       0.250845
# 3044     0.051297          0.003070          0.310789       0.250845
# 3045     0.051297          0.003498          0.380403       0.250845
# 3046     0.051297          0.003213          0.507753       0.250845
#
#       medIncome  popEst2015  povertyPercent  studyPerCap  MedianAge  \
# 0      0.381164    0.025498        0.180995     0.051192   0.028253
# ...

# %%
target_y=data_scaled.iloc[:,2]

# %%
independent_x=data_scaled.iloc[:,3:]

# %%
correlation_matrix=independent_x.corr()
plt.figure(figsize=(20,20))
sns.heatmap(correlation_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %%
len(data.columns)
# Out:
# 31

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Features']=data.columns
vif['data']=[variance_inflation_factor(data.values,i) for i in range(31)]

# %%
vif
# Out:
#                    Features        data
# 0               avgAnnCount   11.581625
# 1          avgDeathsPerYear   35.971140
# 2          TARGET_deathRate   85.855917
# 3             incidenceRate  107.452213
# 4                 medIncome  121.543619
# 5                popEst2015   29.121004
# 6            povertyPercent   46.595474
# 7               studyPerCap    1.138907
# 8                 MedianAge    2.047500
# 9             MedianAgeMale  564.485550
# 10          MedianAgeFemale  679.312662
# 11         AvgHouseholdSize   46.023393
# 12           PercentMarried  609.566392
# 13             PctNoHS18_24    9.766693
# 14               PctHS18_24   25.891788
# 15          PctBachDeg18_24    5.575798
# 16             PctHS25_Over   94.177888
# 17        PctBachDeg25_Over   38.738512
# 18       PctEmployed16_Over  177.231888
# 19     PctUnemployed16_Over   15.669331
# 20       PctPrivateCoverage  592.583857
# 21  PctPrivateCoverageAlone  142.007565
# ...
